# %% [markdown]
# <a href="https://colab.research.google.com/github/soyudea/Optimizacion/blob/main/ReglaFalsaTallerPunto5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Metodo de la regla falsa
# Omar Torres
# ![falpos.gif](data:image/gif;base64,...)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Entrada de datos**

# %%
err = float(input("Digite el error aceptable "))
err_ref = float(input("Digite un error de referencia cual quieraq ejemplo err "))
xl  = float(input("Ingrese la frontera inferior del intervalo "))
xu  = float(input("Ingrese la frontera superior del intervalo "))
# Out:
# Digite el error aceptable 0.001
# Digite un error de referencia cual quieraq ejemplo err 1
# Ingrese la frontera inferior del intervalo -1.2
# Ingrese la frontera superior del intervalo -0.9

# %% [markdown]
# Grafica de f(x) = x^4 + x3 -2
# [0,1]

# %%
def graf_function():
  X = list(np.arange(xl,xu, err))
  #Y=[((x**4)+ 3*(x**3) - 2) for x in X]
  Y=[((x**10) - 1) for x in X]
  plt.title("Funcion")
  plt.xlabel("Y = x^10 - 1")
  plt.ylabel("Y")
  plt.plot(X,Y, "r--")
  plt.axvline(x=-0.92, ymin=0.0, ymax=10)
  plt.grid()
  plt.show()

graf_function()

# %% [markdown]
# **Clase ReglaFalsa**

# %%
from re import S
class ReglaFalsa:
  def __init__(self, xl, xu, error):
     self.__xl = xl
     self.__xu = xu
     self.__error=error
     self.__error_act=0
     self.__err_ref = 1
     self.__xr_i =0
     self.__fxl = 0
     self.__fxu = 1
     self.__fr =2
     self.__fr_old =100
     self.__xr_old = 0
     self.__i =0
     self.__lista_error=[]

  def __printf(self):                              #Imprime los valores parciales de los f(x) y el error
      print("______________________________________________________________________________________________________")
      print("i = ", self.__i)
      print("xl = ",self.__xl, "fxl = ",self.__fxl)
      print("xlu = ",self.__xu, "fxu = ",self.__fxu)
      print("xl = ",self.__xr_old, "fxl = ",self.__fr_old)
      print("error = ",self.__error_act)
      print()

  def __f(self, x):
    fx = ((x**10) - 1)
    return fx

  def __cal_xr(self):
    x_num = self.__fxu*(self.__xl - self.__xu)
    x_denom = self.__fxl - self.__fxu
    xr = self.__xu - (x_num)/x_denom
    return xr

  def __errorAptual(self):
    error=0
    if self.__xr_old != 0:
      error = (  self.__xr_old - self.__xr_i)/self.__xr_old
    self.__err_actual = np.abs(error)
    return self.__err_actual

  def get_lista_errores(self):
    return self.__lista_error

  def cal_raiz(self):
    flag = True
    err = self.__err_ref    #Se inicializa un error para entrar al while
    xr=0
    i=0
    while err > self.__error:
        self.__printf()
        self.__i = self.__i + 1
        fxl = self.__f(self.__xl)
        fxu = self.__f(self.__xu)
        self.__fxl = fxl
        self.__fxu = fxu
        self.__xr_i  = self.__xr_old
        xr = self.__cal_xr()
        self.__fr_old = self.__fr
        fr = self.__f(xr)
        self.__fr = fr
        self.__xr_old = xr
        err =  self.__errorAptual()
        self.__lista_error.append(err)
        self.__error_act =err
        if (fxl)*(fxu) < 0:       #Convergencia
            if fxl*fr <0:    #[xl, xr] contiene la raiz
                self._xl = xl
                self.__xu = xr
            else:
                if fxl*fr:   #[xr, xu] contiene la raiz
                  self.__xl = xr
                  self.__xu = self.__xu
        else:
          flag = False

    return self.__xr_old

# %% [markdown]
# **Funcion main()**

# %%
errores =[]
obj= ReglaFalsa(xl,xu,err)
def main():
  errores = obj.get_lista_errores()
  print("Raiz = ",obj.cal_raiz())
if __name__=='__main__':
   print()
   main()
errores = obj.get_lista_errores()
# Out:
# ______________________________________________________________________________________________________
# i =  0
# xl =  -1.2 fxl =  0
# xlu =  -0.9 fxu =  1
# xl =  0 fxl =  100
# error =  0
#
# ______________________________________________________________________________________________________
# i =  1
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.933440788806461 fxu =  -0.6513215599
# xl =  -0.933440788806461 fxl =  2
# error =  1.0
#
# ______________________________________________________________________________________________________
# i =  2
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9567635495252687 fxu =  -0.4978103654219076
# xl =  -0.9567635495252687 fxl =  -0.4978103654219076
# error =  0.0243767237269648
#
# ______________________________________________________________________________________________________
# i =  3
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9724231357826325 fxu =  -0.3572438903737468
# xl =  -0.9724231357826325 fxl =  -0.3572438903737468
# error =  0.016103675119535896
#
# ______________________________________________________________________________________________________
# i =  4
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9826364734954853 fxu =  -0.24394597497933046
# xl =  -0.9826364734954853 fxl =  -0.24394597497933046
# error =  0.010393810924320169
#
# ______________________________________________________________________________________________________
# i =  5
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9891616515317334 fxu =  -0.16067762207183334
# xl =  -0.9891616515317334 fxl =  -0.16067762207183334
# error =  0.006596675099710682
#
# ______________________________________________________________________________________________________
# i =  6
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9932728035335042 fxu =  -0.10324726475490875
# xl =  -0.9932728035335042 fxl =  -0.10324726475490875
# error =  0.004138995839960234
#
# ______________________________________________________________________________________________________
# i =  7
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.995839551081914 fxu =  -0.06527158812984368
# xl =  -0.995839551081914 fxl =  -0.06527158812984368
# error =  0.0025774709847798233
#
# ______________________________________________________________________________________________________
# i =  8
# xl =  -1.2 fxl =  5.191736422399997
# xlu =  -0.9974327867438276 fxu =  -0.04083414824373832
# xl =  -0.9974327867438276 fxl =  -0.04083414824373832
# error =  0.0015973363650044112
#
# Raiz =  -0.9984181332703661

# %%
def graf_f():
  X = errores
  Y = np.linspace(0, 10, num=15,endpoint=False)
  plt.title("Funcion de error ")
  plt.xlabel("error ")
  plt.ylabel("Y")
  plt.plot(X)
  plt.grid()
  plt.show()
graf_f()

# %%
def graf_function():
  X = list(np.arange(xl,xu, err))
  #Y=[((x**4)+ 3*(x**3) - 2) for x in X]
  Y=[((x**10)- 1) for x in X]
  plt.title("Funcion")
  plt.xlabel("Y = x^10 - 1")
  plt.ylabel("Y")
  plt.plot(X,Y, "r--")
  plt.axvline(x=-0.9984181332703661, ymin=0.0, ymax=10)
  plt.grid()
  plt.show()

graf_function()
