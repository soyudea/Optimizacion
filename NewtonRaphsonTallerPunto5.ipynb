# %% [markdown]
# <a href="https://colab.research.google.com/github/soyudea/Optimizacion/blob/main/NewtonRaphsonTallerPunto5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Diagrama-para-provar-el-metodo-de-Newton-Raphson.webp](data:image/webp;base64,...)

# %% [markdown]
# **Carga de librerías**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols
from sympy import diff
from sympy import sin
from sympy import tanh
from sympy import cos
from scipy.special import shichi, sici
from scipy.misc import derivative

# %% [markdown]
# **Ingreso valor inicial**

# %%
x0  = float(input("Ingrese la frontera inferior del intervalo x0 "))
err = float(input("Ingrese valor del error aceptable "))
# Out:
# Ingrese la frontera inferior del intervalo x0 3.2
# Ingrese valor del error aceptable 0.001

# %% [markdown]
# **Grafica de f(x)  = x^10 -1**

# %%
def graf_f():
  X = list(np.arange(-4, 4, 0.001))
  Y=[(math.tanh(x**2 -9)) for x in X]
  plt.title("Funcion")
  plt.xlabel("f(x) = tanh(x^2-9)")
  plt.ylabel("Y")
  plt.plot(X,Y, "r--")
  plt.axvline(x= 3.2, ymin=0.0, ymax=30)
  plt.grid()
  plt.show()
graf_f()

# %% [markdown]
# **Derivación simbólica**

# %%
x = symbols('x')
y = tanh(x**2 -9)
fprime = diff(y,x)
print(fprime)
# Out:
# 2*x*(1 - tanh(x**2 - 9)**2)

# %% [markdown]
# **Clase Newton_Raphson**

# %%
#Esta clase calcula la raiz de una función**
class NewtonRaphson:
  def __init__(self, x0, err):
    self.__xi = x0
    self.__xlast = 0
    self.__f_last = 0
    self.__err = err
    self.__fd1 = 1
    self.__list_error = []

  def __derive(self, x):                                                        #Calcula simbólicamente la derivada
    fd1 = 2*x*(1 -(tanh(x**2 - 9))**2)
    self.__fd1 = fd1

  def __cal_x_mas(self, x):                                                     #Calcula el Xi+1
    self.__derive(x)
    x_fut = 0
    if self.__fd1 !=0:
       x_fut = x - self.__f_last / self.__fd1
    return x_fut

  def __cal_f(self, x):                                                         #Calcula la función f(x)
      f = math.tanh(x**2 -9)
      return f

  def __printf(self,i, x,f, fd1, dif_x):                                        #Muestra en consola los resultados parciale
      print("_______________________________________Resultados_________________________________________")
      print("i = ",i)
      print("x = ",x)
      print("f(x) = ",f)
      print("f'(x) = ", fd1)
      print("dif_x = ", dif_x)

  def getError(self):                                                           #Retorna lista de errores (Diferencia de las xi)
    return self.__list_error

  def Raiz(self):                                                               #Retorna la raiz
      dif_x = 1
      xlast = 0
      xfut =0
      i = 0
      self.__xi =2.5
      while  np.absolute(dif_x) > err:#
         self.__f_last = self.__cal_f(self.__xi)
         xfut = self.__cal_x_mas(self.__xi)
         self.__printf(i,self.__xi, self.__f_last, self.__fd1, dif_x)
         self.__xlast = self.__xi     #3
         self.__xi = xfut
         dif_x = self.__xi - self.__xlast
         self.__list_error.append(dif_x)
         i += 1

      return self.__f_last,  self.__xlast

# %%
def graf_f():
  X = list(np.arange(-4, 4, 0.001))
  Y=[(math.tanh(x**2 -9)) for x in X]
  plt.title("Funcion")
  plt.xlabel("f(x) = tanh(x^2-9)")
  plt.ylabel("Y")
  plt.plot(X,Y, "r--")
  plt.axvline(x= 3.2, ymin=0.0, ymax=30)
  plt.grid()
  plt.show()
graf_f()

# %% [markdown]
# **Grafica error**

# %% [markdown]
# **Función principal**

# %%
listaError = []
obj = NewtonRaphson(x0, err)
def main():
  f, raiz = obj.Raiz()
  print("_______________________________Resultados de la busqueda de la raiz_____________________________")
  print("Raiz de f(x) = ", raiz)
  print("f(x) = ", f )                                                          #Imprime el valor de la raiz y f(raiz)
if  __name__=='__main__':
  main()
listaError = obj.getError()
# Out:
# _______________________________________Resultados_________________________________________
# i =  0
# x =  2.5
# f(x) =  -0.9918597245682077
# f'(x) =  0.0810714338973956
# dif_x =  1
# _______________________________________Resultados_________________________________________
# i =  1
# x =  14.7343922746391
# f(x) =  1.0
# f'(x) =  0
# dif_x =  12.2343922746391
# _______________________________________Resultados_________________________________________
# i =  2
# x =  0
# f(x) =  -0.999999969540041
# f'(x) =  0
# dif_x =  -14.7343922746391
# _______________________________Resultados de la busqueda de la raiz_____________________________
# Raiz de f(x) =  0
# f(x) =  -0.999999969540041

# %%
xl = 0
xu = 8

def graf_f():
  X = listaError
  Y=[(2*math.sin(x) -(x**2)/10) for x in X]
  plt.title("Funcion de error ")
  plt.xlabel("f(x) = 2*sin(x) - x^2/10")
  plt.ylabel("Y")
  plt.plot(listaError)
  plt.grid()
  plt.show()
graf_f()

# %%
print(6.4*(1 -(math.tanh(9.4-9)**2)))
print(math.tanh(9.4-9))
3.2 - 0.3799/5.476
# Out:
# 5.476088230919536
# 0.37994896225522523
# 3.1306245434623814
